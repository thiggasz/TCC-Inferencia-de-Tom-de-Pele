# %%
from analysis.results_analysis import analyse_results
from src.machine_learning import random_forest, mlp_classifier

# %% [markdown]
# ## ITA°

# %%
ita_fitz = r'C:\Users\thiag\Documents\Faculdade\TCC\TCC-Inferencia-de-Tom-de-Pele\results\ita\ita_fitzpatrick.csv'

analyse_results(ita_fitz, 'ita', 'fitzpatrick')
# Out:
#               precision    recall  f1-score   support
#
#       type i       0.12      0.27      0.17       410
#      type ii       0.30      0.30      0.30      1926
#     type iii       0.33      0.27      0.30      2652
#      type iv       0.32      0.16      0.21      2980
#       type v       0.24      0.14      0.17      2207
#      type vi       0.07      0.44      0.11       425
#
#     accuracy                           0.22     10600
#    macro avg       0.23      0.26      0.21     10600
# weighted avg       0.28      0.22      0.24     10600

# %%
ita_monk = r'C:\Users\thiag\Documents\Faculdade\TCC\TCC-Inferencia-de-Tom-de-Pele\results\ita\ita_monk.csv'

analyse_results(ita_monk, 'ita', 'monk')
# Out:
#               precision    recall  f1-score   support
#
#     scale 01       0.00      0.00      0.00       150
#     scale 02       0.37      0.01      0.03      1243
#     scale 03       0.27      0.02      0.04      1518
#     scale 04       0.18      0.03      0.05      1930
#     scale 05       0.15      0.08      0.11      3174
#     scale 06       0.19      0.40      0.26      1457
#     scale 07       0.06      0.22      0.09       503
#     scale 08       0.07      0.29      0.12       400
#     scale 09       0.05      0.28      0.08       195
#     scale 10       0.02      0.43      0.03        30
#
#     accuracy                           0.12     10600
#    macro avg       0.14      0.18      0.08     10600
# weighted avg       0.19      0.12      0.10     10600

# %% [markdown]
# ## Cluster

# %%
cluster_fitz = r'C:\Users\thiag\Documents\Faculdade\TCC\TCC-Inferencia-de-Tom-de-Pele\results\cluster\clustering_fitzpatrick.csv'

analyse_results(cluster_fitz, 'cluster', 'fitzpatrick')
# Out:
#               precision    recall  f1-score   support
#
#       type i       0.13      0.03      0.05       410
#      type ii       0.37      0.07      0.12      1926
#     type iii       0.34      0.23      0.27      2652
#      type iv       0.28      0.26      0.27      2980
#       type v       0.18      0.20      0.19      2207
#      type vi       0.07      0.51      0.13       425
#
#     accuracy                           0.21     10600
#    macro avg       0.23      0.22      0.17     10600
# weighted avg       0.28      0.21      0.21     10600

# %%
cluster_monk = r'C:\Users\thiag\Documents\Faculdade\TCC\TCC-Inferencia-de-Tom-de-Pele\results\cluster\clustering_monk.csv'

analyse_results(cluster_monk, 'clusterização', 'monk')
# Out:
#               precision    recall  f1-score   support
#
#     scale 01       0.00      0.00      0.00       150
#     scale 02       0.20      0.00      0.00      1243
#     scale 03       0.00      0.00      0.00      1518
#     scale 04       0.22      0.01      0.01      1930
#     scale 05       0.14      0.06      0.08      3174
#     scale 06       0.19      0.44      0.26      1457
#     scale 07       0.06      0.27      0.10       503
#     scale 08       0.09      0.28      0.13       400
#     scale 09       0.05      0.13      0.07       195
#     scale 10       0.01      0.57      0.02        30
#
#     accuracy                           0.11     10600
#    macro avg       0.09      0.18      0.07     10600
# weighted avg       0.14      0.11      0.07     10600

# %% [markdown]
# ## Gemini

# %%
gemini_fitz = r'C:\Users\thiag\Documents\Faculdade\TCC\TCC-Inferencia-de-Tom-de-Pele\results\gemini\gemini_fitzpatrick.csv'

analyse_results(gemini_fitz, 'gemini', 'fitzpatrick')
# Out:
#               precision    recall  f1-score   support
#
#       type i       0.50      0.01      0.01       164
#      type ii       0.66      0.47      0.55      1422
#     type iii       0.54      0.55      0.54      3215
#      type iv       0.52      0.78      0.62      4138
#       type v       0.60      0.13      0.22      1986
#      type vi       0.67      0.76      0.71       170
#
#     accuracy                           0.54     11095
#    macro avg       0.58      0.45      0.44     11095
# weighted avg       0.56      0.54      0.51     11095

# %%
gemini_monk = r'C:\Users\thiag\Documents\Faculdade\TCC\TCC-Inferencia-de-Tom-de-Pele\results\gemini\gemini_monk.csv'

analyse_results(gemini_monk, 'gemini', 'monk')
# Out:
#               precision    recall  f1-score   support
#
#     scale 01       0.08      0.02      0.03        60
#     scale 02       0.32      0.68      0.44       599
#     scale 03       0.26      0.46      0.33      1492
#     scale 04       0.22      0.29      0.25      1921
#     scale 05       0.69      0.54      0.61      4982
#     scale 06       0.23      0.00      0.01      1435
#     scale 07       0.09      0.07      0.08       334
#     scale 08       0.11      0.11      0.11       182
#     scale 09       0.23      0.32      0.27        78
#     scale 10       0.12      0.75      0.20        12
#
#     accuracy                           0.40     11095
#    macro avg       0.23      0.32      0.23     11095
# weighted avg       0.44      0.40      0.39     11095

# %% [markdown]
# ## Random Forest

# %%
random_forest('fitzpatrick_type')
# Out:
# Running Random Forest with (5 folds for the fitzpatrick_type
#
# --- Resultados Globais Validação Cruzada (5 Folds) - Escala: Fitzpatrick_type ---
#               precision    recall  f1-score   support
#
#       type i       0.06      0.01      0.02       410
#      type ii       0.36      0.43      0.39      1926
#     type iii       0.33      0.41      0.37      2652
#      type iv       0.40      0.29      0.34      2980
#       type v       0.51      0.56      0.53      2207
#      type vi       0.14      0.12      0.13       425
#
#     accuracy                           0.38     10600
#    macro avg       0.30      0.30      0.30     10600
# weighted avg       0.38      0.38      0.38     10600

# %%
random_forest('monk_scale')
# Out:
# Running Random Forest with (5 folds for the monk_scale
#
# --- Resultados Globais Validação Cruzada (5 Folds) - Escala: Monk_scale ---
#               precision    recall  f1-score   support
#
#     scale 01       0.05      0.02      0.03       150
#     scale 02       0.26      0.29      0.28      1243
#     scale 03       0.25      0.33      0.28      1518
#     scale 04       0.23      0.24      0.24      1930
#     scale 05       0.64      0.61      0.62      3174
#     scale 06       0.32      0.28      0.30      1457
#     scale 07       0.10      0.04      0.06       503
#     scale 08       0.10      0.11      0.10       400
#     scale 09       0.11      0.10      0.11       195
#     scale 10       0.04      0.03      0.04        30
#
#     accuracy                           0.35     10600
#    macro avg       0.21      0.21      0.21     10600
# weighted avg       0.36      0.35      0.35     10600

# %% [markdown]
# ## MLP

# %%
mlp_classifier('fitzpatrick_type')
# Out:
#               precision    recall  f1-score   support
#
#       type i       0.11      0.07      0.09       410
#      type ii       0.34      0.36      0.35      1926
#     type iii       0.33      0.34      0.33      2652
#      type iv       0.36      0.35      0.36      2980
#       type v       0.44      0.47      0.46      2207
#      type vi       0.14      0.10      0.11       425
#
#     accuracy                           0.35     10600
#    macro avg       0.29      0.28      0.28     10600
# weighted avg       0.35      0.35      0.35     10600

# %%
mlp_classifier('monk_scale')
# Out:
#               precision    recall  f1-score   support
#
#     scale 01       0.04      0.03      0.03       150
#     scale 02       0.26      0.26      0.26      1243
#     scale 03       0.23      0.25      0.24      1518
#     scale 04       0.24      0.28      0.26      1930
#     scale 05       0.56      0.59      0.58      3174
#     scale 06       0.29      0.25      0.27      1457
#     scale 07       0.09      0.06      0.08       503
#     scale 08       0.10      0.09      0.09       400
#     scale 09       0.14      0.11      0.12       195
#     scale 10       0.00      0.00      0.00        30
#
#     accuracy                           0.34     10600
#    macro avg       0.20      0.19      0.19     10600
# weighted avg       0.33      0.34      0.33     10600
